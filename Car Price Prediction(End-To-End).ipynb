# %% [markdown]
# ## Car Price Prediction

# %%
# Primary Libraries


import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
url1 = '/content/drive/MyDrive/Kaggle_Datasets/Regression/CarPrice_Assignment.csv'
url2 = '/content/drive/MyDrive/Kaggle_Datasets/Machine Learning /Classification /car data.csv'
df = pd.read_csv(url2)
df.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
print(df.shape)
print(df.info())
# Out:
# (301, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# None

# %%
print(df.isnull().sum())
print(df.describe())
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
for i in ['Fuel_Type','Seller_Type','Transmission','Owner']:
    print(i, df[i].unique())
# Out:
# Fuel_Type ['Petrol' 'Diesel' 'CNG']
# Seller_Type ['Dealer' 'Individual']
# Transmission ['Manual' 'Automatic']
# Owner [0 1 3]

# %%
final_df=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Seller_Type Transmission Owner
# 0  2014           3.35           5.59  ...       Dealer       Manual     0
# 1  2013           4.75           9.54  ...       Dealer       Manual     0
# 2  2017           7.25           9.85  ...       Dealer       Manual     0
# 3  2011           2.85           4.15  ...       Dealer       Manual     0
# 4  2014           4.60           6.87  ...       Dealer       Manual     0
#
# [5 rows x 8 columns]

# %%
# Creating a Current year column
final_df['Current_Year'] = 2021

# Finding age of the car
final_df['No.of_Years'] = final_df['Current_Year'] - final_df['Year']

# Drop year column
final_df.drop(['Year','Current_Year'],axis=1,inplace=True)
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  ... Transmission Owner No.of_Years
# 0           3.35           5.59       27000  ...       Manual     0           7
# 1           4.75           9.54       43000  ...       Manual     0           8
# 2           7.25           9.85        6900  ...       Manual     0           4
# 3           2.85           4.15        5200  ...       Manual     0          10
# 4           4.60           6.87       42450  ...       Manual     0           7
#
# [5 rows x 8 columns]

# %%
# One hot encoding
final_df = pd.get_dummies(final_df,drop_first=True)
print(final_df.shape)
final_df.head()
# Out:
# (301, 9)
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %%
# Correlation Matrix
final_df.corr().style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col0,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col1,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col2,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col3,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col4,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col5,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col6,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col7,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col1{
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col2{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col3,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col4,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col7,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col8,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col6,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col2,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col5,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col0,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col5{
#             background-color:  #1c6ab0;
#             color:  #f1f1f1;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row0_col6{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col0{
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col2{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col3{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col4{
#             background-color:  #cadef0;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col5{
#             background-color:  #2575b7;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col6{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col7{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row1_col8{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col0{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col1{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col3{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col4{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col5{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col6{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col7{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row2_col8{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col0{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col1{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col2,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col4{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col4{
#             background-color:  #aacfe5;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col5{
#             background-color:  #79b5d9;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col6{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col7{
#             background-color:  #85bcdc;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row3_col8{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col0{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col1{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col2{
#             background-color:  #4b98ca;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col3{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col5{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col6{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col7{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row4_col8{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col0{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col1{
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col2{
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col3,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row8_col3{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col4{
#             background-color:  #dce9f6;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col7,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col3{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row5_col8,#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col3{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col0{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col1{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col4{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col7{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row6_col8{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col2{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col5{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col6{
#             background-color:  #3484bf;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row7_col8{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_6c2c08d4_2e96_11ec_ae52_0242ac1c0002row8_col0{
#             background-color:  #

# %%
# Pairplot
sns.pairplot(final_df)

# %%
# get correlations of each features in dataset
corrmat = df.corr()
top_corr_feat = corrmat.index

plt.figure(figsize=(10,8))

# Plot correlation matrix
sns.heatmap(df[top_corr_feat].corr(),annot=True,cmap='RdYlGn')

# %%
X = final_df.iloc[:,1:]
y = final_df.iloc[:,0]
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %% [markdown]
# ### Model Creation

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
model.feature_importances_
# Out:
# array([0.38405042, 0.04256235, 0.00046476, 0.07430694, 0.22804153,
#        0.01105489, 0.12826978, 0.13124932])

# %%
# plot graph of feature importances for better visualization
feat_imp = pd.Series(model.feature_importances_,index=X.columns)

feat_imp.nlargest(5).plot.barh()

# %%
# Train, Test, Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
# Random Search
from sklearn.model_selection import RandomizedSearchCV


# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
#Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.4s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.5s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.5s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.5s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.5s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.5s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   1.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   1.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   1.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   1.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   1.3s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.4s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.3s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.3s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.5s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.4s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   1.0s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.9s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   46.4s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=10, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'max_depth': 25,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1000}

# %%
rf_random.best_score_
# Out:
# -3.993542717055015

# %%
y_pred=rf_random.predict(X_test)

# %%
sns.distplot(y_test-y_pred)

# %%
plt.scatter(y_test,y_pred)

# %%
# Scores
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test,y_pred ))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 0.8868578021978019
# MSE: 3.9851910123120935
# RMSE: 1.9962943200620729

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)

# %%
# END
